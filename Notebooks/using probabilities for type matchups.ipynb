# %% [markdown]
# # using matrices with probabilities  for comparing type match ups as suggested in
# # Pokemon's (Actual) 19th Type According to Simple Math
# # https://www.youtube.com/watch?v=Ov85T9xO3Wk
